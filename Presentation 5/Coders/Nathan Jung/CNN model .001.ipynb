# %%
import torchvision
import torch
from PIL import Image
from sklearn.metrics import confusion_matrix, accuracy_score
import torch.nn as nn
from torch import optim
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, datasets
from sklearn.model_selection import train_test_split
import os
import pandas as pd
import time
import random

# %%
# Replace last classifier to only handle 2 cases, one benign one high grade
num_classes = 2
model = torchvision.models.alexnet(pretrained = True)
# replace the last classifier
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
# Out:
# C:\Users\nhj4\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\nhj4\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for param in model.parameters():
    param.requires_grad = False
for param in model.classifier[6].parameters():
    param.requires_grad = True

# %%
labels = pd.read_csv('case_grade_match.csv')

# %%
# Need to group the patches by their cases, and also need to randomly split, the function below will group the cases
def group_patches(patch_dir):
    case_patches = {}
    for filename in os.listdir(patch_dir):
        # If the image size is less than a kilobyte, don't use the patch
        if os.path.getsize(os.path.join(patch_dir, filename)) < 2000:
            continue
        # If 'patched' in filename, not an actual patch
        if 'patched_' in filename:
            continue
        elif filename.endswith('.png'):
            case_num = int(filename.split('_')[1])
            if case_num not in case_patches:
                case_patches[case_num] = []
            case_patches[case_num].append(os.path.join(patch_dir, filename))
    return case_patches

class PNGDataset(Dataset):
    def __init__(self, case_patches, labels_df, transform=None):
        self.case_patches = case_patches
        self.labels_df = labels_df
        self.transform = transform
        self.image_paths = []
        self.labels = []

        for case_num, patches in case_patches.items():
            label = labels_df.loc[labels_df['Case'] == case_num, 'Class'].values[0]
            label = 0 if label == 1 else 1
            for patch_path in patches:
                self.image_paths.append(patch_path)
                self.labels.append(label)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        # Get patches, if they are not patch, don't use the patch
        image = Image.open(image_path).convert('RGB')
        # Get the label information using the labels dataframe based on case number
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        return image, label

# Group the patches
patches = group_patches('Patches/')

# Get case numbers and their labels
case_nums = list(patches.keys())
dataset = labels.loc[[(int(x)-1) for x in case_nums]]
# Remove those that are equal to 2
noindex = dataset.Class != 2.0
X = dataset[noindex].Case
y = dataset[noindex].Class
train, test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify = y, random_state=40)

# Create the training patches and the test patches
train_patches = {case_num: patches[int(case_num)] for case_num in train}
test_patches = {case_num: patches[int(case_num)] for case_num in test}


transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Generate the actual datasets for the models
train_dataset = PNGDataset(train_patches, labels, transform=transform)
test_dataset = PNGDataset(test_patches, labels, transform = transform)
train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
start = time.time()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 1000  # Number of epochs
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

patience = 0
best_loss = 100000

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)


        optimizer.zero_grad()


        outputs = model(images)
        loss = criterion(outputs, labels)


        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader)
    if epoch_loss < best_loss:
        #print('Model Saved!')
        #torch.save(model.state_dict(), f'model_epoch_{epoch + 1}.pth')
        best_loss = epoch_loss
        patience = 0
    else:
        patience += 1
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Patience: {patience}, Best Loss: {best_loss:.4f}')
    
    if patience >= 50:
        print(f'Early stopping at epoch {epoch + 1}')
        break
end = time.time()
elapsed = end - start
minutes = int(elapsed // 60)
seconds = int(elapsed % 60)
print(f'Time taken: {minutes} minutes, {seconds} seconds')
# Out:
# Epoch [1/1000], Loss: 0.4960, Patience: 0, Best Loss: 0.4960
# Epoch [2/1000], Loss: 0.4105, Patience: 0, Best Loss: 0.4105
# Epoch [3/1000], Loss: 0.3900, Patience: 0, Best Loss: 0.3900
# Epoch [4/1000], Loss: 0.3726, Patience: 0, Best Loss: 0.3726
# Epoch [5/1000], Loss: 0.3693, Patience: 0, Best Loss: 0.3693
# Epoch [6/1000], Loss: 0.3647, Patience: 0, Best Loss: 0.3647
# Epoch [7/1000], Loss: 0.3680, Patience: 1, Best Loss: 0.3647
# Epoch [8/1000], Loss: 0.3512, Patience: 0, Best Loss: 0.3512
# Epoch [9/1000], Loss: 0.3556, Patience: 1, Best Loss: 0.3512
# Epoch [10/1000], Loss: 0.3574, Patience: 2, Best Loss: 0.3512
# Epoch [11/1000], Loss: 0.3494, Patience: 0, Best Loss: 0.3494
# Epoch [12/1000], Loss: 0.3496, Patience: 1, Best Loss: 0.3494
# Epoch [13/1000], Loss: 0.3420, Patience: 0, Best Loss: 0.3420
# Epoch [14/1000], Loss: 0.3458, Patience: 1, Best Loss: 0.3420
# Epoch [15/1000], Loss: 0.3460, Patience: 2, Best Loss: 0.3420
# Epoch [16/1000], Loss: 0.3431, Patience: 3, Best Loss: 0.3420
# Epoch [17/1000], Loss: 0.3535, Patience: 4, Best Loss: 0.3420
# Epoch [18/1000], Loss: 0.3365, Patience: 0, Best Loss: 0.3365
# Epoch [19/1000], Loss: 0.3361, Patience: 0, Best Loss: 0.3361
# Epoch [20/1000], Loss: 0.3444, Patience: 1, Best Loss: 0.3361
# Epoch [21/1000], Loss: 0.3476, Patience: 2, Best Loss: 0.3361
# Epoch [22/1000], Loss: 0.3544, Patience: 3, Best Loss: 0.3361
# Epoch [23/1000], Loss: 0.3450, Patience: 4, Best Loss: 0.3361
# Epoch [24/1000], Loss: 0.3443, Patience: 5, Best Loss: 0.3361
# Epoch [25/1000], Loss: 0.3402, Patience: 6, Best Loss: 0.3361
# Epoch [26/1000], Loss: 0.3369, Patience: 7, Best Loss: 0.3361
# Epoch [27/1000], Loss: 0.3420, Patience: 8, Best Loss: 0.3361
# Epoch [28/1000], Loss: 0.3476, Patience: 9, Best Loss: 0.3361
# Epoch [29/1000], Loss: 0.3417, Patience: 10, Best Loss: 0.3361
# Epoch [30/1000], Loss: 0.3370, Patience: 11, Best Loss: 0.3361
# Epoch [31/1000], Loss: 0.3315, Patience: 0, Best Loss: 0.3315
# Epoch [32/1000], Loss: 0.3451, Patience: 1, Best Loss: 0.3315
# Epoch [33/1000], Loss: 0.3404, Patience: 2, Best Loss: 0.3315
# Epoch [34/1000], Loss: 0.3361, Patience: 3, Best Loss: 0.3315
# Epoch [35/1000], Loss: 0.3472, Patience: 4, Best Loss: 0.3315
# Epoch [36/1000], Loss: 0.3453, Patience: 5, Best Loss: 0.3315
# Epoch [37/1000], Loss: 0.3317, Patience: 6, Best Loss: 0.3315
# Epoch [38/1000], Loss: 0.3483, Patience: 7, Best Loss: 0.3315
# Epoch [39/1000], Loss: 0.3383, Patience: 8, Best Loss: 0.3315
# Epoch [40/1000], Loss: 0.3394, Patience: 9, Best Loss: 0.3315
# Epoch [41/1000], Loss: 0.3356, Patience: 10, Best Loss: 0.3315
# Epoch [42/1000], Loss: 0.3457, Patience: 11, Best Loss: 0.3315
# Epoch [43/1000], Loss: 0.3368, Patience: 12, Best Loss: 0.3315
# Epoch [44/1000], Loss: 0.3443, Patience: 13, Best Loss: 0.3315
# Epoch [45/1000], Loss: 0.3478, Patience: 14, Best Loss: 0.3315
# Epoch [46/1000], Loss: 0.3369, Patience: 15, Best Loss: 0.3315
# Epoch [47/1000], Loss: 0.3400, Patience: 16, Best Loss: 0.3315
# Epoch [48/1000], Loss: 0.3365, Patience: 17, Best Loss: 0.3315
# Epoch [49/1000], Loss: 0.3353, Patience: 18, Best Loss: 0.3315
# Epoch [50/1000], Loss: 0.3434, Patience: 19, Best Loss: 0.3315
# Epoch [51/1000], Loss: 0.3430, Patience: 20, Best Loss: 0.3315
# Epoch [52/1000], Loss: 0.3379, Patience: 21, Best Loss: 0.3315
# Epoch [53/1000], Loss: 0.3380, Patience: 22, Best Loss: 0.3315
# Epoch [54/1000], Loss: 0.3345, Patience: 23, Best Loss: 0.3315
# Epoch [55/1000], Loss: 0.3370, Patience: 24, Best Loss: 0.3315
# Epoch [56/1000], Loss: 0.3337, Patience: 25, Best Loss: 0.3315
# Epoch [57/1000], Loss: 0.3326, Patience: 26, Best Loss: 0.3315
# Epoch [58/1000], Loss: 0.3432, Patience: 27, Best Loss: 0.3315
# Epoch [59/1000], Loss: 0.3360, Patience: 28, Best Loss: 0.3315
# Epoch [60/1000], Loss: 0.3331, Patience: 29, Best Loss: 0.3315
# Epoch [61/1000], Loss: 0.3503, Patience: 30, Best Loss: 0.3315
# Epoch [62/1000], Loss: 0.3371, Patience: 31, Best Loss: 0.3315
# Epoch [63/1000], Loss: 0.3376, Patience: 32, Best Loss: 0.3315
# Epoch [64/1000], Loss: 0.3383, Patience: 33, Best Loss: 0.3315
# Epoch [65/1000], Loss: 0.3414, Patience: 34, Best Loss: 0.3315
# Epoch [66/1000], Loss: 0.3374, Patience: 35, Best Loss: 0.3315
# Epoch [67/1000], Loss: 0.3339, Patience: 36, Best Loss: 0.3315
# Epoch [68/1000], Loss: 0.3373, Patience: 37, Best Loss: 0.3315
# Epoch [69/1000], Loss: 0.3311, Patience: 0, Best Loss: 0.3311
# Epoch [70/1000], Loss: 0.3420, Patience: 1, Best Loss: 0.3311
# Epoch [71/1000], Loss: 0.3467, Patience: 2, Best Loss: 0.3311
# Epoch [72/1000], Loss: 0.3368, Patience: 3, Best Loss: 0.3311
# Epoch [73/1000], Loss: 0.3350, Patience: 4, Best Loss: 0.3311
# Epoch [74/1000], Loss: 0.3323, Patience: 5, Best Loss: 0.3311
# Epoch [75/1000], Loss: 0.3528, Patience: 6, Best Loss: 0.3311
# Epoch [76/1000], Loss: 0.3427, Patience: 7, Best Loss: 0.3311
# Epoch [77/1000], Loss: 0.3363, Patience: 8, Best Loss: 0.3311
# Epoch [78/1000], Loss: 0.3432, Patience: 9, Best Loss: 0.3311
# Epoch [79/1000], Loss: 0.3448, Patience: 10, Best Loss: 0.3311
# Epoch [80/1000], Loss: 0.3420, Patience: 11, Best Loss: 0.3311
# Epoch [81/1000], Loss: 0.3372, Patience: 12, Best Loss: 0.3311
# Epoch [82/1000], Loss: 0.3316, Patience: 13, Best Loss: 0.3311
# Epoch [83/1000], Loss: 0.3382, Patience: 14, Best Loss: 0.3311
# Epoch [84/1000], Loss: 0.3327, Patience: 15, Best Loss: 0.3311
# Epoch [85/1000], Loss: 0.3423, Patience: 16, Best Loss: 0.3311
# Epoch [86/1000], Loss: 0.3306, Patience: 0, Best Loss: 0.3306
# Epoch [87/1000], Loss: 0.3450, Patience: 1, Best Loss: 0.3306
# Epoch [88/1000], Loss: 0.3442, Patience: 2, Best Loss: 0.3306
# Epoch [89/1000], Loss: 0.3444, Patience: 3, Best Loss: 0.3306
# Epoch [90/1000], Loss: 0.3312, Patience: 4, Best Loss: 0.3306
# Epoch [91/1000], Loss: 0.3454, Patience: 5, Best Loss: 0.3306
# Epoch [92/1000], Loss: 0.3573, Patience: 6, Best Loss: 0.3306
# Epoch [93/1000], Loss: 0.3481, Patience: 7, Best Loss: 0.3306
# Epoch [94/1000], Loss: 0.3293, Patience: 0, Best Loss: 0.3293
# Epoch [95/1000], Loss: 0.3318, Patience: 1, Best Loss: 0.3293
# Epoch [96/1000], Loss: 0.3345, Patience: 2, Best Loss: 0.3293
# Epoch [97/1000], Loss: 0.3464, Patience: 3, Best Loss: 0.3293
# Epoch [98/1000], Loss: 0.3375, Patience: 4, Best Loss: 0.3293
# Epoch [99/1000], Loss: 0.3458, Patience: 5, Best Loss: 0.3293
# Epoch [100/1000], Loss: 0.3402, Patience: 6, Best Loss: 0.3293
# Epoch [101/1000], Loss: 0.3410, Patience: 7, Best Loss: 0.3293
# Epoch [102/1000], Loss: 0.3489, Patience: 8, Best Loss: 0.3293
# Epoch [103/1000], Loss: 0.3378, Patience: 9, Best Loss: 0.3293
# Epoch [104/1000], Loss: 0.3348, Patience: 10, Best Loss: 0.3293
# Epoch [105/1000], Loss: 0.3465, Patience: 11, Best Loss: 0.3293
# Epoch [106/1000], Loss: 0.3371, Patience: 12, Best Loss: 0.3293
# Epoch [107/1000], Loss: 0.3410, Patience: 13, Best Loss: 0.3293
# Epoch [108/1000], Loss: 0.3443, Patience: 14, Best Loss: 0.3293
# Epoch [109/1000], Loss: 0.3398, Patience: 15, Best Loss: 0.3293
# Epoch [110/1000], Loss: 0.3341, Patience: 16, Best Loss: 0.3293
# Epoch [111/1000], Loss: 0.3382, Patience: 17, Best Loss: 0.3293
# Epoch [112/1000], Loss: 0.3451, Patience: 18, Best Loss: 0.3293
# Epoch [113/1000], Loss: 0.3362, Patience: 19, Best Loss: 0.3293
# Epoch [114/1000], Loss: 0.3398, Patience: 20, Best Loss: 0.3293
# Epoch [115/1000], Loss: 0.3335, Patience: 21, Best Loss: 0.3293
# Epoch [116/1000], Loss: 0.3441, Patience: 22, Best Loss: 0.3293
# Epoch [117/1000], Loss: 0.3507, Patience: 23, Best Loss: 0.3293
# Epoch [118/1000], Loss: 0.3480, Patience: 24, Best Loss: 0.3293
# Epoch [119/1000], Loss: 0.3442, Patience: 25, Best Loss: 0.3293
# Epoch [120/1000], Loss: 0.3362, Patience: 26, Best Loss: 0.3293
# Epoch [121/1000], Loss: 0.3425, Patience: 27, Best Loss: 0.3293
# Epoch [122/1000], Loss: 0.3407, Patience: 28, Best Loss: 0.3293
# Epoch [123/1000], Loss: 0.3360, Patience: 29, Best Loss: 0.3293
# Epoch [124/1000], Loss: 0.3378, Patience: 30, Best Loss: 0.3293
# Epoch [125/1000], Loss: 0.3363, Patience: 31, Best Loss: 0.3293
# Epoch [126/1000], Loss: 0.3460, Patience: 32, Best Loss: 0.3293
# Epoch [127/1000], Loss: 0.3378, Patience: 33, Best Loss: 0.3293
# Epoch [128/1000], Loss: 0.3292, Patience: 0, Best Loss: 0.3292
# Epoch [129/1000], Loss: 0.3458, Patience: 1, Best Loss: 0.3292
# Epoch [130/1000], Loss: 0.3285, Patience: 0, Best Loss: 0.3285
# Epoch [131/1000], Loss: 0.3397, Patience: 1, Best Loss: 0.3285
# Epoch [132/1000], Loss: 0.3383, Patience: 2, Best Loss: 0.3285
# Epoch [133/1000], Loss: 0.3444, Patience: 3, Best Loss: 0.3285
# Epoch [134/1000], Loss: 0.3380, Patience: 4, Best Loss: 0.3285
# Epoch [135/1000], Loss: 0.3444, Patience: 5, Best Loss: 0.3285
# Epoch [136/1000], Loss: 0.3309, Patience: 6, Best Loss: 0.3285
# Epoch [137/1000], Loss: 0.3396, Patience: 7, Best Loss: 0.3285
# Epoch [138/1000], Loss: 0.3295, Patience: 8, Best Loss: 0.3285
# Epoch [139/1000], Loss: 0.3439, Patience: 9, Best Loss: 0.3285
# Epoch [140/1000], Loss: 0.3444, Patience: 10, Best Loss: 0.3285
# Epoch [141/1000], Loss: 0.3494, Patience: 11, Best Loss: 0.3285
# Epoch [142/1000], Loss: 0.3448, Patience: 12, Best Loss: 0.3285
# Epoch [143/1000], Loss: 0.3521, Patience: 13, Best Loss: 0.3285
# Epoch [144/1000], Loss: 0.3450, Patience: 14, Best Loss: 0.3285
# Epoch [145/1000], Loss: 0.3338, Patience: 15, Best Loss: 0.3285
# Epoch [146/1000], Loss: 0.3412, Patience: 16, Best Loss: 0.3285
# Epoch [147/1000], Loss: 0.3399, Patience: 17, Best Loss: 0.3285
# Epoch [148/1000], Loss: 0.3326, Patience: 18, Best Loss: 0.3285
# Epoch [149/1000], Loss: 0.3472, Patience: 19, Best Loss: 0.3285
# Epoch [150/1000], Loss: 0.3427, Patience: 20, Best Loss: 0.3285
# Epoch [151/1000], Loss: 0.3381, Patience: 21, Best Loss: 0.3285
# Epoch [152/1000], Loss: 0.3397, Patience: 22, Best Loss: 0.3285
# Epoch [153/1000], Loss: 0.3322, Patience: 23, Best Loss: 0.3285
# Epoch [154/1000], Loss: 0.3316, Patience: 24, Best Loss: 0.3285
# Epoch [155/1000], Loss: 0.3437, Patience: 25, Best Loss: 0.3285
# Epoch [156/1000], Loss: 0.3365, Patience: 26, Best Loss: 0.3285
# Epoch [157/1000], Loss: 0.3465, Patience: 27, Best Loss: 0.3285
# Epoch [158/1000], Loss: 0.3518, Patience: 28, Best Loss: 0.3285
# Epoch [159/1000], Loss: 0.3421, Patience: 29, Best Loss: 0.3285
# Epoch [160/1000], Loss: 0.3468, Patience: 30, Best Loss: 0.3285
# Epoch [161/1000], Loss: 0.3403, Patience: 31, Best Loss: 0.3285
# Epoch [162/1000], Loss: 0.3400, Patience: 32, Best Loss: 0.3285
# Epoch [163/1000], Loss: 0.3491, Patience: 33, Best Loss: 0.3285
# Epoch [164/1000], Loss: 0.3382, Patience: 34, Best Loss: 0.3285
# Epoch [165/1000], Loss: 0.3364, Patience: 35, Best Loss: 0.3285
# Epoch [166/1000], Loss: 0.3355, Patience: 36, Best Loss: 0.3285
# Epoch [167/1000], Loss: 0.3421, Patience: 37, Best Loss: 0.3285
# Epoch [168/1000], Loss: 0.3522, Patience: 38, Best Loss: 0.3285
# Epoch [169/1000], Loss: 0.3335, Patience: 39, Best Loss: 0.3285
# Epoch [170/1000], Loss: 0.3398, Patience: 40, Best Loss: 0.3285
# Epoch [171/1000], Loss: 0.3551, Patience: 41, Best Loss: 0.3285
# Epoch [172/1000], Loss: 0.3491, Patience: 42, Best Loss: 0.3285
# Epoch [173/1000], Loss: 0.3387, Patience: 43, Best Loss: 0.3285
# Epoch [174/1000], Loss: 0.3519, Patience: 44, Best Loss: 0.3285
# Epoch [175/1000], Loss: 0.3409, Patience: 45, Best Loss: 0.3285
# Epoch [176/1000], Loss: 0.3340, Patience: 46, Best Loss: 0.3285
# Epoch [177/1000], Loss: 0.3327, Patience: 47, Best Loss: 0.3285
# Epoch [178/1000], Loss: 0.3322, Patience: 48, Best Loss: 0.3285
# Epoch [179/1000], Loss: 0.3332, Patience: 49, Best Loss: 0.3285
# Epoch [180/1000], Loss: 0.3403, Patience: 50, Best Loss: 0.3285
# Early stopping at epoch 180
# Time taken: 145 minutes, 55 seconds

# %%
pred = []
labels = []
with torch.no_grad():
    for images, label in test_dataloader:
        images, label = images.to(device), label.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        labels.append(label)
        pred.append(predicted)

pred = torch.cat(pred).cpu()
labels = torch.cat(labels).cpu()
accuracy = accuracy_score(labels, pred)
print(f'Accuracy: {accuracy}')
confusion_matrix(labels, pred)
# Out:
# Accuracy: 0.6399278954484002
# array([[ 451, 1176],
#        [ 422, 2389]], dtype=int64)
