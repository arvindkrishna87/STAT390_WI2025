# %%
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
import cv2
import random

# %% [markdown]
# ### Takes an image of a tissue slice and an image of an epithelium extract from Qupath an inputs

# %%
def apply_mask():

    # Open the JPG and PNG images
    jpg_path = '/Users/annaroney/Downloads/Stat390_Anna/QuPath_work/1:22 patching test/data/2/thumbnail.jpg' # path to the tissue slice
    png_mask_path = '/Users/annaroney/Downloads/Stat390_Anna/QuPath_work/1:22 patching test/export/h1857578B  h&e_ROI_2-labels.png' # path to the epithelium slice
    
    jpg_image = Image.open(jpg_path).convert("RGB")
    png_mask = Image.open(png_mask_path).convert("RGBA")

    # Resize the mask to match the JPG dimensions if they differ
    if jpg_image.size != png_mask.size:
        png_mask = png_mask.resize(jpg_image.size, Image.LANCZOS)

    # Convert both images to numpy arrays
    jpg_array = np.array(jpg_image)
    mask_array = np.array(png_mask)

    # Create a mask for the PNG: True where the PNG is not white
    non_white_mask = ~np.all(mask_array[:, :, :3] > 200, axis=-1)  # Mask where PNG is not white

    # Create the final output image with a black background
    final_image_array = np.zeros_like(jpg_array)

    # Add white for stroma: Original white pixels in the JPG
    stroma_mask = np.all(jpg_array > 200, axis=-1)  # White pixels in JPG
    final_image_array[stroma_mask] = [0, 0, 0]  # Set stroma to white

    # Add red for mask: Areas in the PNG mask
    final_image_array[non_white_mask] = [254, 0, 0]  # Set mask areas to red
    mask = final_image_array
    # Set remaining original JPG pixels (not covered by PNG) to black
    non_masked_area = ~(stroma_mask | non_white_mask)  # Pixels not in stroma or mask
    final_image_array[non_masked_area] = [255, 255, 255]  # Set uncovered pixels to black

    # Convert back to PIL image
    final_image = Image.fromarray(final_image_array)

    return final_image, mask


   

image, mask = apply_mask()
filename = '/Users/annaroney/Downloads/Stat390_Anna/QuPath_work/1:22 patching test/epitheliummask.png' # where you want your output to go
image.save(filename)

# Display the final image
plt.imshow(image)
plt.show()

mask[mask == 255] = 0

# %% [markdown]
# ## Notes on the following code block:
#
# - Uses Alyssa's code as a base
# - makes patches the exact width of the epithelium
# - no iteration involved
# - currently takes longer to run than Alyssa's initial code
# - likely covers less of the epithelium due to the patch size equaling epithelium exactly
# - Can edit by making patch size (1.x * epithelium width)

# %%
# Load the image
image_path = '/Users/annaroney/Downloads/Stat390_Anna/QuPath_work/1:22 patching test/epitheliummask.png'
image = cv2.imread(image_path)

# Function to check if a region contains black, white, and non-black-white mask
def contains_black_white_mask(region):
    contains_black = np.any(np.all(region == [0, 0, 0], axis=-1))
    contains_white = np.any(np.all(region == [255, 255, 255], axis=-1))
    contains_mask = np.any((region != [0, 0, 0]).all(axis=-1) & (region != [255, 255, 255]).all(axis=-1))
    return contains_black and contains_white and contains_mask

# Mask for black areas, white areas, and non-black-white pixels
black_mask = cv2.inRange(image, np.array([0, 0, 0]), np.array([0, 0, 0]))
white_mask = cv2.inRange(image, np.array([255, 255, 255]), np.array([255, 255, 255]))
non_black_white_mask = mask

non_black_white_mask = np.any(non_black_white_mask>0, axis = 2).astype(int)

# Calculate distance to the nearest black and white pixels
black_distance = cv2.distanceTransform(255 - black_mask, cv2.DIST_L2, 3)
white_distance = cv2.distanceTransform(255 - white_mask, cv2.DIST_L2, 3)

# Find coordinates of non-black and non-white pixels
coordinates = np.column_stack(np.where(non_black_white_mask > 0))

# Define the ratio tolerance range for balanced points
min_ratio, max_ratio = .7, 1.3

# Filter coordinates to only include balanced points
balanced_points = [
    coord for coord in coordinates
    if min_ratio <= (black_distance[coord[0], coord[1]] / white_distance[coord[0], coord[1]]) <= max_ratio
]

# Function to determine tissue orientation
def determine_orientation(mask):
    # Find non-zero epithelium pixels
    non_zero_coords = np.column_stack(np.where(mask > 0))
    y_min, y_max = non_zero_coords[:, 0].min(), non_zero_coords[:, 0].max()
    x_min, x_max = non_zero_coords[:, 1].min(), non_zero_coords[:, 1].max()
    # Compare height and width of the bounding box
    height = y_max - y_min
    width = x_max - x_min
    return "vertical" if height > width else "horizontal"

# Determine tissue orientation
tissue_orientation = determine_orientation(non_black_white_mask)
print(f"Tissue orientation: {tissue_orientation}")

# Updated function to calculate epithelium width
def calculate_epithelium_width(row_or_col, mask, orientation):
    if orientation == "horizontal":
        # Use vertical slice for horizontally oriented tissue
        slice_mask = mask[:, row_or_col] # looks at the column
    else:
        # Use horizontal slice for vertically oriented tissue
        slice_mask = mask[row_or_col, :]

    # Convert the mask slice to binary
    binary_slice = (slice_mask > 0).astype(int) # pixels along a column of the image where 1 represents epithelium

    # Anna new code
    # 1 means change from 0 to 1 and -1 means change from 1 to 0 in the binary slice
    diffs = np.diff(np.concatenate(([0],binary_slice,[0])))
    starts = np.where(diffs == 1)[0]
    ends = np.where(diffs == -1)[0]
    widths = ends - starts
    middle_idx = np.floor((starts + ends)/2).astype(int)
    width_and_idx = np.column_stack((widths, middle_idx))
    return width_and_idx


# Function to calculate overlap
def calculate_overlap(new_coords, existing_coords):
    if len(new_coords) == 0:
        return 0 
    else:
        new_coords_set = set(new_coords)  # Convert to set of coordinates
        existing_coords_set = set(existing_coords)  # Convert to set of covered coordinates
        overlap = len(new_coords_set.intersection(existing_coords_set)) / len(new_coords_set)
        return overlap

# Initialize variables
max_attempts = 1000
covered_coordinates = set()
rectangles = []
attempts = 0

# Start generating squares using only balanced points as starting locations
while len(balanced_points) > 0 and attempts < 1000:
    attempts += 1
    # Randomly select a new center point for the square from balanced points
    random.seed(attempts)
    random_coord = random.choice(balanced_points)
    center_x, center_y = int(random_coord[1]), int(random_coord[0])

    # Dynamically calculate the initial_size based on epithelium width
    if tissue_orientation == "horizontal":
        width_and_idx = calculate_epithelium_width(center_x, non_black_white_mask, tissue_orientation)
    else:
        width_and_idx = calculate_epithelium_width(center_y, non_black_white_mask, tissue_orientation)
    
    # Anna new code
    new_square_coords_list = []

    for w, mid in width_and_idx:
        half_side = w // 2
        left = center_x - half_side
        top = mid - half_side
        right = center_x + half_side
        bottom = mid + half_side
        
        square_coords = np.array([(x, y) for x in range(left, right + 1) for y in range(top, bottom + 1)])

        square_coords_set = set(map(tuple, square_coords))

        # Check overlap with existing covered coordinates (starts as empty set)
        overlap = len(square_coords_set.intersection(covered_coordinates))/len(square_coords_set)

        # idk what this is for - anna
        vertical_preference = False
        
        if overlap <= 0.2: # if they aren't overlapping that much
            covered_coordinates.update(square_coords_set) # then now we have those coords covered
            rectangles.append((left, top, right, bottom)) # and that becomes a patch

            # Draw the rectangle
            color = (0, 255, 0) if vertical_preference else (255, 0, 0)
            cv2.rectangle(image, (left, top), (right, bottom), color, 2)

            # Remove these coordinates from the balanced points
            remove = np.isin(balanced_points, square_coords).all(axis = 1)
            balanced_points = np.array(balanced_points)
            balanced_points = balanced_points[~remove]

# Display the resulting image with all rectangles
plt.figure(figsize=(10, 10))
plt.title("Image with Dynamic Square Sizes (Based on Orientation)")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

lengths = []

# Print dimensions of each final rectangle as Length x Width
for i, (left, top, right, bottom) in enumerate(rectangles, 1):
    length = bottom - top  # Height of the rectangle
    width = right - left   # Width of the rectangle
    lengths.append(length)
    
    print(f"Rectangle {i} dimensions: Length = {length} pixels, Width = {width} pixels")

import statistics as st
print(np.mean(lengths))
print(st.mode(lengths))
# Out:
# Tissue orientation: horizontal
# Rectangle 1 dimensions: Length = 24 pixels, Width = 24 pixels
# Rectangle 2 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 3 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 4 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 5 dimensions: Length = 46 pixels, Width = 46 pixels
# Rectangle 6 dimensions: Length = 22 pixels, Width = 22 pixels
# Rectangle 7 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 8 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 9 dimensions: Length = 24 pixels, Width = 24 pixels
# Rectangle 10 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 11 dimensions: Length = 48 pixels, Width = 48 pixels
# Rectangle 12 dimensions: Length = 26 pixels, Width = 26 pixels
# Rectangle 13 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 14 dimensions: Length = 24 pixels, Width = 24 pixels
# Rectangle 15 dimensions: Length = 14 pixels, Width = 14 pixels
# Rectangle 16 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 17 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 18 dimensions: Length = 18 pixels, Width = 18 pixels
# Rectangle 19 dimensions: Length = 22 pixels, Width = 22 pixels
# Rectangle 20 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 21 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 22 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 23 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 24 dimensions: Length = 30 pixels, Width = 30 pixels
# Rectangle 25 dimensions: Length = 30 pixels, Width = 30 pixels
# Rectangle 26 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 27 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 28 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 29 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 30 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 31 dimensions: Length = 30 pixels, Width = 30 pixels
# Rectangle 32 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 33 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 34 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 35 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 36 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 37 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 38 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 39 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 40 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 41 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 42 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 43 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 44 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 45 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 46 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 47 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 48 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 49 dimensions: Length = 14 pixels, Width = 14 pixels
# Rectangle 50 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 51 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 52 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 53 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 54 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 55 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 56 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 57 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 58 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 59 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 60 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 61 dimensions: Length = 16 pixels, Width = 16 pixels
# Rectangle 62 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 63 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 64 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 65 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 66 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 67 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 68 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 69 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 70 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 71 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 72 dimensions: Length = 20 pixels, Width = 20 pixels
# Rectangle 73 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 74 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 75 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 76 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 77 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 78 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 79 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 80 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 81 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 82 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 83 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 84 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 85 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 86 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 87 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 88 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 89 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 90 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 91 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 92 dimensions: Length = 28 pixels, Width = 28 pixels
# Rectangle 93 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 94 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 95 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 96 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 97 dimensions: Length = 18 pixels, Width = 18 pixels
# Rectangle 98 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 99 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 100 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 101 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 102 dimensions: Length = 18 pixels, Width = 18 pixels
# Rectangle 103 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 104 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 105 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 106 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 107 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 108 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 109 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 110 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 111 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 112 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 113 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 114 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 115 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 116 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 117 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 118 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 119 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 120 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 121 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 122 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 123 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 124 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 125 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 126 dimensions: Length = 10 pixels, Width = 10 pixels
# Rectangle 127 dimensions: Length = 24 pixels, Width = 24 pixels
# Rectangle 128 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 129 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 130 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 131 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 132 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 133 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 134 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 135 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 136 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 137 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 138 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 139 dimensions: Length = 12 pixels, Width = 12 pixels
# Rectangle 140 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 141 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 142 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 143 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 144 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 145 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 146 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 147 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 148 dimensions: Length = 8 pixels, Width = 8 pixels
# Rectangle 149 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 150 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 151 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 152 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 153 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 154 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 155 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 156 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 157 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 158 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 159 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 160 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 161 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 162 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 163 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 164 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 165 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 166 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 167 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 168 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 169 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 170 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 171 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 172 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 173 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 174 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 175 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 176 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 177 dimensions: Length = 4 pixels, Width = 4 pixels
# Rectangle 178 dimensions: Length = 0 pixels, Width = 0 pixels
# Rectangle 179 dimensions: Length = 6 pixels, Width = 6 pixels
# Rectangle 180 dimensions: Length = 2 pixels, Width = 2 pixels
# Rectangle 181 dimensions: Length = 2 pixels, Width = 2 pixels
# 6.707182320441989
# 2

# %% [markdown]
# ## Evaluation

# %%
# Calculate the total mask area
total_mask_area = np.sum(non_black_white_mask > 0)

# Initialize variables to track patch areas and overlap
total_patch_area = 0            
patch_area_outside_mask = 0     
overlap_area = 0                

patch_masks = [] # stores binary masks for each patch so we can calculate overlaps later

# Loop through each patch defined by its bounding box
for (left, top, right, bottom) in rectangles:

    # Create a binary mask for the current patch
    patch_mask = np.zeros_like(non_black_white_mask, dtype=np.uint8)
    patch_mask[max(0, top):min(image.shape[0], bottom), max(0, left):min(image.shape[1], right)] = 1 # set the region corresponding to the current patch to 1 within image bounds

    # Calculate the area of the current patch
    patch_area = np.sum(patch_mask)
    total_patch_area += patch_area    

    # Calculate the area of the patch that falls outside the mask
    area_outside_mask = np.sum(patch_mask & (non_black_white_mask == 0))
    patch_area_outside_mask += area_outside_mask  

    # Calculate overlap with previously added patches
    for prev_patch in patch_masks:
        overlap_area += np.sum(patch_mask & prev_patch)

    # Add the current patch's binary mask to the list for future overlap calculations
    patch_masks.append(patch_mask)

# Percentage calculations
percent_mask_covered = (total_patch_area - patch_area_outside_mask) / total_mask_area * 100
percent_outside_mask = patch_area_outside_mask / total_patch_area * 100
percent_overlap = overlap_area / total_patch_area * 100

# Number of patches
num_patches = len(rectangles)

# Output results
print(f"% of Mask Area Covered: {percent_mask_covered:.2f}%")
print(f"% of Patch Area Outside Mask: {percent_outside_mask:.2f}%")
print(f"Number of Patches: {num_patches}")
print(f"% Patch Area Overlap: {percent_overlap:.2f}%")
# Out:
# % of Mask Area Covered: 76.14%
# % of Patch Area Outside Mask: 20.54%
# Number of Patches: 181
# % Patch Area Overlap: 1.47%
